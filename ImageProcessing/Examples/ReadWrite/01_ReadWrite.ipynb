# %%
# import glob
import pandas as pd 
import cv2
import sys

pathCustom = ['/Users/pannawis/Projects/Git/ImageProcessing']
for ipath in pathCustom:
    if not(ipath in sys.path):
        print(f'Adding path:{ipath}')
        sys.path.append(ipath)

import wedoimage as wedoimg

# %%
pathImg = '/Users/pannawis/Projects/Git/ImageProcessing/ObjectDetection/images/person_street.jpg'

flag_read = 1 # read color
img_read  = cv2.imread(pathImg,flag_read)

wedoimg.imshowCV(img_read)
print(img_read.shape)
# Out:
# (675, 1080, 3)

# %% [markdown]
# # Region of interest

# %%
ROI = img_read[200:600,400:500,:] 
wedoimg.imshowCV(ROI)

# %% [markdown]
# # Convert to gray scale

# %%
ROI_gray = cv2.cvtColor(ROI, cv2.COLOR_BGR2GRAY)
wedoimg.imshowCV(ROI_gray)
